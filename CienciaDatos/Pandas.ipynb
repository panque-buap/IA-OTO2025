# %%
import pandas as pd

# %%
dataframe = pd.DataFrame([[1,1,1],[2,2,2],[3,3]], columns=["col1", "col2", "col3"])
display(dataframe)
# Out:
#    col1  col2  col3
# 0     1     1   1.0
# 1     2     2   2.0
# 2     3     3   NaN

# %%
df = pd.read_csv('customers.csv')
display(df)
# Out:
#       Index      Customer Id First Name   Last Name                   Company  \
# 0         1  EB54EF1154C3A78    Heather    Callahan              Mosley-David
# 1         2  10dAcafEBbA5FcA   Kristina     Ferrell  Horn, Shepard and Watson
# 2         3  67DAB15Ebe4BE4a     Briana    Andersen               Irwin-Oneal
# 3         4  6d350C5E5eDB4EE      Patty       Ponce          Richardson Group
# 4         5  5820deAdCF23EFe   Kathleen   Mccormick              Carson-Burch
# ...     ...              ...        ...         ...                       ...
# 9995   9996  DD0caa06ebf217c     Meghan       Cline            Richardson LLC
# 9996   9997  C1C62ff90D0AfED   Jeremiah        Pena               Hodge-Nixon
# 9997   9998  2EfAa6Fe435A7DA      Peggy         Key                  Vang LLC
# 9998   9999  5dB06C3Fab5CCCb       Evan    Humphrey                 Gould Ltd
# 9999  10000  9903e8fF4D8Ff0F    Melissa  Montgomery              Burns-Holden
#
# ...

# %%
df.head(2)
# Out:
#    Index      Customer Id First Name Last Name                   Company  \
# 0      1  EB54EF1154C3A78    Heather  Callahan              Mosley-David
# 1      2  10dAcafEBbA5FcA   Kristina   Ferrell  Horn, Shepard and Watson
#
#                City  Country       Phone 1             Phone 2  \
# 0  Lake Jeffborough   Norway  043-797-5229        915.112.1727
# 1        Aaronville  Andorra  932-062-1802  (209)172-7124x3651
#
#                           Email Subscription Date                   Website
# 0  urangel@espinoza-francis.net        2020-08-26   http://www.escobar.org/
# 1       xreese@hall-donovan.com        2020-04-27  https://tyler-pugh.info/

# %%
df.tail(2)
# Out:
#       Index      Customer Id First Name   Last Name       Company  \
# 9998   9999  5dB06C3Fab5CCCb       Evan    Humphrey     Gould Ltd
# 9999  10000  9903e8fF4D8Ff0F    Melissa  Montgomery  Burns-Holden
#
#                 City  Country                Phone 1               Phone 2  \
# 9998  Camachochester    Niger       001-465-242-9979  001-639-955-2116x751
# 9999      Sparkstown  Tunisia  +1-889-682-9490x65400    423.632.2539x98740
#
#                                      Email Subscription Date  \
# 9998  velazquezjessica@villegas-wilcox.com        2020-04-14
# 9999               ngallagher@martinez.com        2020-06-27
#
#                       Website
# 9998  https://www.payne.info/
# 9999        http://nixon.net/

# %%
df.columns
# Out:
# Index(['Index', 'Customer Id', 'First Name', 'Last Name', 'Company', 'City',
#        'Country', 'Phone 1', 'Phone 2', 'Email', 'Subscription Date',
#        'Website'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Index              10000 non-null  int64
#  1   Customer Id        10000 non-null  object
#  2   First Name         10000 non-null  object
#  3   Last Name          10000 non-null  object
#  4   Company            10000 non-null  object
#  5   City               10000 non-null  object
#  6   Country            10000 non-null  object
#  7   Phone 1            10000 non-null  object
#  8   Phone 2            10000 non-null  object
#  9   Email              10000 non-null  object
#  10  Subscription Date  10000 non-null  object
#  11  Website            10000 non-null  object
# dtypes: int64(1), object(11)
# memory usage: 937.6+ KB

# %%
df2 = pd.read_csv('2017_delays.csv')

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113339 entries, 0 to 113338
# Data columns (total 12 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   YEAR           113339 non-null  int64
#  1   MONTH_NUM      113339 non-null  int64
#  2   MONTH_MON      113339 non-null  object
#  3   FLT_DATE       113339 non-null  object
#  4   APT_ICAO       113339 non-null  object
#  5   APT_NAME       113339 non-null  object
#  6   STATE_NAME     113339 non-null  object
#  7   FLT_DEP_1      113339 non-null  int64
#  8   FLT_DEP_IFR_2  37553 non-null   float64
#  9   DLY_ATC_PRE_2  37553 non-null   float64
#  10  FLT_DEP_3      94762 non-null   float64
#  11  DLY_ATC_PRE_3  94762 non-null   float64
# dtypes: float64(4), int64(3), object(5)
# memory usage: 10.4+ MB

# %%
df.describe()
# Out:
#              Index
# count  10000.00000
# mean    5000.50000
# std     2886.89568
# min        1.00000
# 25%     2500.75000
# 50%     5000.50000
# 75%     7500.25000
# max    10000.00000

# %%
display(df["First Name"])
# Out:
# 0        Heather
# 1       Kristina
# 2         Briana
# 3          Patty
# 4       Kathleen
#           ...
# 9995      Meghan
# 9996    Jeremiah
# 9997       Peggy
# 9998        Evan
# 9999     Melissa
# Name: First Name, Length: 10000, dtype: object

# %%
lista = df["First Name"].unique().tolist()
print(len(lista))
# Out:
# 690

# %%
df.sample(5)
# Out:
#       Index      Customer Id First Name Last Name                    Company  \
# 1668   1669  AbA8dd430553bF1      Derek    French                Fritz Group
# 5711   5712  dBC92Cde4BbFDbe     Janice      Wall                 Pena Group
# 899     900  d83d4dEaDB1B320    Miranda  Callahan  Pope, Adkins and Randolph
# 8083   8084  badafD27D41DA79     Bonnie     Stark    Taylor, Horne and Weeks
# 3817   3818  470fA12Ba18942C      Lydia  Castillo                Fleming PLC
#
#                      City                 Country               Phone 1  \
# 1668  Lake Raymondborough                Botswana  +1-562-498-9218x0652
# 5711       Manningborough                Cambodia            7663763712
# 899             Haneybury  Bosnia and Herzegovina          623-353-5668
# 8083             New Todd                    Iran     733.015.0162x7074
# 3817              Annside                  Gambia       +1-513-572-7249
#
# ...

# %%
df.loc[1668:1700]   #Ubica la fila con el indice proporcionado
# Out:
#       Index      Customer Id First Name  Last Name  \
# 1668   1669  AbA8dd430553bF1      Derek     French
# 1669   1670  7Ee95bBaacC6663     Gordon      Walsh
# 1670   1671  b545De0695cAAdC     Hayden   Mckenzie
# 1671   1672  d59AfC9b255Aa8b       Adam   Garrison
# 1672   1673  C39c9e820C737DD  Charlotte    Hendrix
# 1673   1674  40AC39c8647eF80    Jocelyn     Cuevas
# 1674   1675  8A17ce96e29cF2f       Greg   Crawford
# 1675   1676  7Dd9A7e1dbfdBaE        Tom   Galloway
# 1676   1677  A9A1d18Ba443F0E     Jerome     Ortega
# 1677   1678  FC62774BEddF749    Makayla     Potter
# 1678   1679  539C67dE0EAF5f3    Eduardo  Singleton
# 1679   1680  43ea26e15bf1469    Deborah   Espinoza
# 1680   1681  5Cbf937eAF42AAC     Sophia      Scott
# 1681   1682  cC1dCaC11c9ffbC      Sarah      Walls
# 1682   1683  07EAE4DF7625ddF    Makayla     Ibarra
# 1683   1684  6D810B88eBBDEE4    Natasha  Nicholson
# 1684   1685  924ba7a4BFE7Deb    Vincent      Mccoy
# ...

# %%
df.loc[1668:1700, ["Country", "Company"]]   #Ubica la fila con el indice proporcionado
# Out:
#                         Country                            Company
# 1668                   Botswana                        Fritz Group
# 1669                      Qatar           Vega, Potter and Skinner
# 1670                    Vanuatu                   Beasley and Sons
# 1671                    Bermuda                        Clayton Ltd
# 1672                 Guadeloupe                     Conley-Cochran
# 1673                      Congo                        Meadows LLC
# 1674                    Burundi    Gibson, Galloway and Williamson
# 1675      Sao Tome and Principe                      Gill-Mccarthy
# 1676  Saint Pierre and Miquelon                      Solomon Group
# 1677                     Gambia                          Vance Ltd
# 1678                      Chile                       Fox-Guerrero
# 1679                     Rwanda                          Kelly Inc
# 1680                    Bahamas                    Bartlett-Hardin
# ...

# %%
df.iloc[1668:1700, [4, 6]]   #Ubica la fila con el indice proporcionado
# Out:
#                                 Company                    Country
# 1668                        Fritz Group                   Botswana
# 1669           Vega, Potter and Skinner                      Qatar
# 1670                   Beasley and Sons                    Vanuatu
# 1671                        Clayton Ltd                    Bermuda
# 1672                     Conley-Cochran                 Guadeloupe
# 1673                        Meadows LLC                      Congo
# 1674    Gibson, Galloway and Williamson                    Burundi
# 1675                      Gill-Mccarthy      Sao Tome and Principe
# 1676                      Solomon Group  Saint Pierre and Miquelon
# 1677                          Vance Ltd                     Gambia
# 1678                       Fox-Guerrero                      Chile
# 1679                          Kelly Inc                     Rwanda
# 1680                    Bartlett-Hardin                    Bahamas
# ...

# %%
df.loc[1668, "Country"] = "Thailand"

# %%
df.loc[1668]
# Out:
# Index                                        1669
# Customer Id                       AbA8dd430553bF1
# First Name                                  Derek
# Last Name                                  French
# Company                               Fritz Group
# City                          Lake Raymondborough
# Country                                  Thailand
# Phone 1                      +1-562-498-9218x0652
# Phone 2                         (125)614-1450x972
# Email                williamcline@rowe-bishop.com
# Subscription Date                      2021-10-21
# Website                     http://www.kirby.com/
# Name: 1668, dtype: object

# %%
df.sort_values(["Country"],ascending=False)
# Out:
#       Index      Customer Id First Name Last Name                 Company  \
# 2553   2554  7DDe7Fdf17fCaca      Faith      Wise  Ward, Mills and Gordon
# 3363   3364  Acba2F1393E296C    Kaitlin     Crane                Frye Ltd
# 5065   5066  FfE765Fbb850DC3      Jorge  Galloway              Spence LLC
# 1326   1327  b1c4F3fA04D5d6a   Caroline   Harding          Hardy and Sons
# 2850   2851  ABbCB5EDa8c9aFd    Claudia    Harmon           Payne-Douglas
# ...     ...              ...        ...       ...                     ...
# 5999   6000  2D1AfB6fc2ee4Ac      Katie   Schmitt           Roberson-Kerr
# 5756   5757  cE0a9F2ba934afa   Kathleen     Crane             Vincent PLC
# 3893   3894  1Ec1b1ffE94e3FF       Rose     Tyler             Gamble-Kemp
# 2986   2987  Da67B8699D8aDd4    Derrick   Leonard            Johnston PLC
# 9088   9089  bfc3B455Dd2f4bd     Sophia   Schultz         Brooks and Sons
#
#                       City      Country               Phone 1  \
# ...

# %%
df2.sample(5)
# Out:
#        YEAR  MONTH_NUM MONTH_MON    FLT_DATE APT_ICAO              APT_NAME  \
# 94851  2017         11       NOV  2017-11-01     LFLI             Annemasse
# 81928  2017          9       SEP  2017-09-21     ESSB    Stockholm - Bromma
# 38307  2017          5       MAY  2017-05-04     LFRG   Deauville-Normandie
# 79620  2017          9       SEP  2017-09-14     EDDB  Berlin - Brandenburg
# 27817  2017          3       MAR  2017-03-31     LKMT               Ostrava
#
#            STATE_NAME  FLT_DEP_1  FLT_DEP_IFR_2  DLY_ATC_PRE_2  FLT_DEP_3  \
# 94851          France          1            NaN            NaN        NaN
# 81928          Sweden        116            NaN            NaN       91.0
# 38307          France          3            NaN            NaN        NaN
# 79620         Germany        164            NaN            NaN      116.0
# 27817  Czech Republic          7            NaN            NaN        4.0
#
#        DLY_ATC_PRE_3
# 94851            NaN
# ...

# %%
df2.loc[df2["MONTH_NUM"]>= 7]
df2.loc[df2["MONTH_NUM"]>= 7, ["STATE_NAME", "FLT_DEP_1"]]
df2[df2["MONTH_NUM"]>= 7][["STATE_NAME", "FLT_DEP_1"]]
# Out:
#         STATE_NAME  FLT_DEP_1
# 56218      Belgium         16
# 56219      Belgium        285
# 56220      Belgium         77
# 56221      Belgium         25
# 56222      Belgium          7
# ...            ...        ...
# 113334  Montenegro         15
# 113335    Slovakia         12
# 113336     Armenia         32
# 113337     Georgia         37
# 113338     Ukraine         79
#
# [57121 rows x 2 columns]

# %%
df2.sample(5)
ndf = df2[ (df2["MONTH_NUM"]>= 7) & (df2["STATE_NAME"] == "Spain")]
ndf.count()
# Out:
# YEAR             8655
# MONTH_NUM        8655
# MONTH_MON        8655
# FLT_DATE         8655
# APT_ICAO         8655
# APT_NAME         8655
# STATE_NAME       8655
# FLT_DEP_1        8655
# FLT_DEP_IFR_2    2146
# DLY_ATC_PRE_2    2146
# FLT_DEP_3        6523
# DLY_ATC_PRE_3    6523
# dtype: int64

# %%
df.sample(5)
# Out:
#       Index      Customer Id First Name  Last Name                    Company  \
# 677     678  9cdF03a6B65b1BE     Stacie     Turner             Carrillo-Lynch
# 2972   2973  Bcb2292edE2d18D       Jade       Diaz           Odonnell-Hopkins
# 9860   9861  2BAdF35eCCFBAbA     Dennis    Higgins                 Mclean PLC
# 1040   1041  83C9AAe7188Cf88     Jordan  Contreras             Dorsey-Merritt
# 8392   8393  Db2f1dD4D11363a   Stefanie       Soto  Morales, Grant and Holder
#
#                   City     Country                Phone 1  \
# 677   East Heatherport   Nicaragua   001-024-760-6772x416
# 2972       East Howard       Ghana  +1-615-809-3030x69473
# 9860       Gailchester   Nicaragua       698-152-9668x578
# 1040      East Zachary     Algeria     866.727.2664x74196
# 8392        Dorseyview  Montenegro       001-229-828-3310
#
#                      Phone 2                                Email  \
# 677       (353)642-4648x1291              daltonevans@keller.info
# ...

# %%
ndf2 = df[df["First Name"].str.contains("Stacie", case=True)]
display(ndf2)
ndf2.count()
# Out:
#       Index      Customer Id First Name   Last Name  \
# 486     487  fcAE0CcFcDf7370     Stacie         Ali
# 677     678  9cdF03a6B65b1BE     Stacie      Turner
# 811     812  8A9eAF9fce144E3     Stacie      Romero
# 975     976  2Be8ac81ed1C7fe     Stacie         May
# 1956   1957  e30D09bcC5EaDEC     Stacie       Reyes
# 3453   3454  8484EBAd0518576     Stacie  Hutchinson
# 5058   5059  F2e4E5B7cAC4C62     Stacie       Perez
# 5641   5642  AACa6B7562DA780     Stacie       Gibbs
# 8022   8023  7FAbeEEC1b8549B     Stacie        Ball
# 8025   8026  CED37cEFE1CA5aE     Stacie  Cunningham
#
#                                Company              City           Country  \
# 486                     Hancock-Pineda         Port Seth              Peru
# 677                     Carrillo-Lynch  East Heatherport         Nicaragua
# 811           Moss, Elliott and Carter         New Becky  Marshall Islands
# 975                         Fields Inc       East Adrian        Montenegro
# ...

# %%
ndf3 = df[df["First Name"].str.contains("Stacie|Jade", case=False, regex=True)]
display(ndf3)
# Out:
# Empty DataFrame
# Columns: [Index, Customer Id, First Name, Last Name, Company, City, Country, Phone 1, Phone 2, Email, Subscription Date, Website]
# Index: []

# %%
filtered_df = df[df['First Name'].str.contains('Stac|Jade', case=False, regex=True)]

# %%
filtered_df
# Out:
#       Index      Customer Id First Name   Last Name  \
# 184     185  abe39219A467866       Jade     Leonard
# 486     487  fcAE0CcFcDf7370     Stacie         Ali
# 677     678  9cdF03a6B65b1BE     Stacie      Turner
# 811     812  8A9eAF9fce144E3     Stacie      Romero
# 975     976  2Be8ac81ed1C7fe     Stacie         May
# 1880   1881  8df2ba29eCeCFbd       Jade   Frederick
# 1956   1957  e30D09bcC5EaDEC     Stacie       Reyes
# 2002   2003  Fc1AEA19E7D000B       Jade       Oneal
# 2972   2973  Bcb2292edE2d18D       Jade        Diaz
# 3453   3454  8484EBAd0518576     Stacie  Hutchinson
# 5058   5059  F2e4E5B7cAC4C62     Stacie       Perez
# 5641   5642  AACa6B7562DA780     Stacie       Gibbs
# 5987   5988  F3D4b4B8fEa3ad4       Jade     Daniels
# 6386   6387  7aC902B9BB093fC       Jade      Powers
# 6408   6409  AeEaeDc36fAa1BC       Jade     Sweeney
# 6565   6566  f9D6e9069d6a17c       Jade       Noble
# 6723   6724  cF7F3FFD67aCC5d       Jade      Hoover
# ...

# %%
df.sample(5)
# Out:
#       Index      Customer Id First Name Last Name  \
# 7764   7765  edecD07D8BbD8Ce      April  Jacobson
# 106     107  0778d8Decad8147  Christine   Manning
# 508     509  EE6E4E0DAa47eed      Allen  Santiago
# 8157   8158  CAf9bfbca2cf3CA        Bob    Sutton
# 3619   3620  A6d69E1Cac8bB22     Sheena     Weeks
#
#                             Company               City          Country  \
# 7764                    Maynard Inc  West Susanborough          Ireland
# 106           Carr, Harvey and Webb       East Eduardo         Slovenia
# 508   Humphrey, Mclean and Mitchell      Port Annefort  Kyrgyz Republic
# 8157                     Daniel LLC         South Eric            Nepal
# 3619          Mooney, Diaz and Hale           Deanstad        Guatemala
#
#                     Phone 1                Phone 2  \
# 7764        +1-023-215-2948       286.887.9438x127
# 106           (099)652-7937             0410407343
# 508   001-415-113-5755x8454       001-455-039-7388
# ...

# %%
df[df["Country"].isin(["Ireland", "Slovenia", "Nepal"])]
# Out:
#       Index      Customer Id First Name Last Name                   Company  \
# 2         3  67DAB15Ebe4BE4a     Briana  Andersen               Irwin-Oneal
# 64       65  DC63a02BDa14af4   Nicholas   Mcclure        Roy, Myers and Fox
# 68       69  B5F6D5dB5eBDfcE        Ann     Ayala             Walton-Carter
# 106     107  0778d8Decad8147  Christine   Manning     Carr, Harvey and Webb
# 254     255  dFAc465E9Ccc3a6       Kara      Pugh           Proctor-Garrett
# ...     ...              ...        ...       ...                       ...
# 9599   9600  68D16f428AEbf69   Nicholas  Calderon               Mack-Wilson
# 9638   9639  e98652AD9E24eaD    Whitney      Reid  Hodge, Carson and Valdez
# 9687   9688  e9E9c663c3A4Bd0      Tyler  Robinson            Morrison-Greer
# 9832   9833  E26dcA79F4B20ef        Ian   Donovan         Villanueva-Holder
# 9833   9834  F5BF07f577b1a3c     Isabel     Flynn          Gomez-Strickland
#
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=10000, step=1)
